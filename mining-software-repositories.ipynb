# %%
import json
import pandas as pd

f = open('./dataset/Java/window_1.json')
data = json.load(f)

# %%
len(data['data']['search']['edges'])
# Out:
# 20

# %%
repo_info = data['data']['search']['edges'][0]
repo_info['node']
# Out:
# {'name': 'JavaGuide',
#  'createdAt': '2018-05-07T13:27:00Z',
#  'description': '「Java学习+面试指南」一份涵盖大部分 Java 程序员所需要掌握的核心知识。准备 Java 面试，首选 JavaGuide！',
#  'id': 'MDEwOlJlcG9zaXRvcnkxMzI0NjQzOTU=',
#  'databaseId': 132464395,
#  'homepageUrl': 'https://javaguide.cn',
#  'stargazerCount': 139851,
#  'forkCount': 45235,
#  'watchers': {'totalCount': 4530},
#  'issues': {'totalCount': 951},
#  'allowUpdateBranch': False,
#  'pullRequests': {'totalCount': 1202},
#  'repositoryTopics': {'nodes': [{'topic': {'name': 'java'}},
#    {'topic': {'name': 'jvm'}},
#    {'topic': {'name': 'interview'}},
#    {'topic': {'name': 'redis'}},
#    {'topic': {'name': 'spring'}},
#    {'topic': {'name': 'mysql'}},
#    {'topic': {'name': 'zookeeper'}},
#    {'topic': {'name': 'algorithms'}},
#    {'topic': {'name': 'system'}},
#    {'topic': {'name': 'system-design'}}]},
#  'languages': {'edges': [{'node': {'name': 'Java'}},
#    {'node': {'name': 'Shell'}},
#    {'node': {'name': 'JavaScript'}}]},
# ...

# %%
# Save as: java_1.json (1-> 1000)
